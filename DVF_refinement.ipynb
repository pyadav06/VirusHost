# %% [markdown]
# <a href="https://colab.research.google.com/github/pyadav06/VirusHost/blob/main/DVF_refinement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from zipfile import ZipFile
file_name = "/content/test.zip"

with ZipFile(file_name, 'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
 import os
 import pandas as pd  
 import numpy as np
 dir= '/content/test/'
 newdir='/content/test-refined/'
 os.mkdir(newdir)
 directories = os.listdir(dir)
 y = sorted(directories)
 print(y)

#k= []
for files in y:
  print (dir+files)
  a = os.listdir(dir+files)
  os.mkdir(newdir+files)
  #print(a)
  print (dir+files+'/'+ a[0])
  k = dir+files+'/'+ a[0]
  f = pd.read_csv (k, sep='\t')
  #print (f)
  df = pd.DataFrame(f)
  #print (df)
  refined = df[df['pvalue']< 0.05]
  print(refined)
  refined.to_csv(newdir+files+'/'+ a[0], index=False)
  
  

  #np.savetxt(newdir+files+'/'+ a[0], refined.values)
# Out:
# ['Rhizo_B73_MAG_00001-dvf-output', 'Rhizo_B73_MAG_00002-dvf-output', 'Rhizo_B73_MAG_00003-dvf-output', 'Rhizo_B73_MAG_00004-dvf-output', 'Rhizo_B73_MAG_00005-dvf-output', 'Rhizo_B73_MAG_00006-dvf-output', 'Rhizo_B73_MAG_00007-dvf-output', 'Rhizo_B73_MAG_00008-dvf-output', 'Rhizo_B73_MAG_00009-dvf-output']
# /content/test/Rhizo_B73_MAG_00001-dvf-output
# /content/test/Rhizo_B73_MAG_00001-dvf-output/final-viral-combined.fa_gt1500bp_dvfpred.txt
#                    name   len     score    pvalue
# 1  c_000000076833||full  3189  0.644269  0.037578
# /content/test/Rhizo_B73_MAG_00002-dvf-output
# /content/test/Rhizo_B73_MAG_00002-dvf-output/final-viral-combined.fa_gt1500bp_dvfpred.txt
#                    name   len     score    pvalue
# 1  c_000000021950||full  2404  0.728813  0.030724
# /content/test/Rhizo_B73_MAG_00003-dvf-output
# /content/test/Rhizo_B73_MAG_00003-dvf-output/final-viral-combined.fa_gt1500bp_dvfpred.txt
#                     name   len     score    pvalue
# 1   c_000000034317||full  2401  0.998934  0.003720
# 2   c_000000143073||full  1853  0.959014  0.012520
# 3   c_000000136647||full  3297  0.970884  0.010669
# 4   c_000000085740||full  1896  0.615679  0.040449
# 6   c_000000031411||full  3892  0.583357  0.044169
# 10  c_000000069921||full  5831  0.642231  0.037786
# 11  c_000000114807||full  6623  0.979198  0.009423
# 13  c_000000076449||full  1613  0.605134  0.041714
# 15  c_000000062908||full  2013  0.999916  0.001530
# 16  c_000000103645||full  3704  0.999865  0.001869
# 17  c_000000018841||full  4541  0.999960  0.001057
# 18  c_000000127623||full  2853  0.999976  0.000850
# 19  c_000000103356||full  3785  0.999438  0.002965
# 20  c_000000072461||full  4291  0.999767  0.002115
# /content/test/Rhizo_B73_MAG_00004-dvf-output
# /content/test/Rhizo_B73_MAG_00004-dvf-output/final-viral-combined.fa_gt1500bp_dvfpred.txt
#                     name   len     score    pvalue
# 11  c_000000085614||full  1600  0.708387  0.032499
# 16  c_000000083303||full  2051  0.857198  0.021017
# 21  c_000000047130||full  5667  0.869219  0.020205
# /content/test/Rhizo_B73_MAG_00005-dvf-output
# /content/test/Rhizo_B73_MAG_00005-dvf-output/final-viral-combined.fa_gt1500bp_dvfpred.txt
#                     name   len     score    pvalue
# 14  c_000000043015||full  2981  0.750100  0.029232
# 24  c_000000043022||full  2198  0.626783  0.039486
# /content/test/Rhizo_B73_MAG_00006-dvf-output
# /content/test/Rhizo_B73_MAG_00006-dvf-output/final-viral-combined.fa_gt1500bp_dvfpred.txt
#                     name   len     score    pvalue
# 5   c_000000082646||full  2402  0.600586  0.042262
# 12  c_000000035483||full  1908  0.811801  0.024303
# 13  c_000000090997||full  2031  0.980029  0.009253
# 16  c_000000113477||full  1721  0.869561  0.020168
# 18  c_000000017206||full  1726  0.885066  0.018902
# 19  c_000000009381||full  2850  0.755707  0.028949
# 21  c_000000017655||full  4850  0.678834  0.034859
# /content/test/Rhizo_B73_MAG_00007-dvf-output
# /content/test/Rhizo_B73_MAG_00007-dvf-output/final-viral-combined.fa_gt1500bp_dvfpred.txt
# Empty DataFrame
# Columns: [name, len, score, pvalue]
# Index: []
# /content/test/Rhizo_B73_MAG_00008-dvf-output
# /content/test/Rhizo_B73_MAG_00008-dvf-output/final-viral-combined.fa_gt1500bp_dvfpred.txt
# Empty DataFrame
# Columns: [name, len, score, pvalue]
# Index: []
# /content/test/Rhizo_B73_MAG_00009-dvf-output
# /content/test/Rhizo_B73_MAG_00009-dvf-output/final-viral-combined.fa_gt1500bp_dvfpred.txt
#                     name   len     score    pvalue
# 8   c_000000054696||full  2021  0.673488  0.035256
# 10  c_000000070557||full  1720  0.934250  0.015201

# %%
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-87-82dc09c634ce> in <module>()
#       4
#       5 for files in k:
# ----> 6   f = pd.read_csv (files, sep='\t')
#       7   #print (f)
#       8   df = pd.DataFrame(f)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# IsADirectoryError: [Errno 21] Is a directory: '/'

# %%
rm -r test-refined
