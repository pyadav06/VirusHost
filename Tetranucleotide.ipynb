# %% [markdown]
# <a href="https://colab.research.google.com/github/pyadav06/VirusHost/blob/main/Tetranucleotide.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install bio
# Out:
# Collecting bio
#   Downloading bio-1.3.3-py3-none-any.whl (271 kB)
#      |████████████████████████████████| 271 kB 5.2 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from bio) (4.63.0)
# Collecting biopython>=1.79
#   Downloading biopython-1.79-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 48.9 MB/s
# Collecting mygene
#   Downloading mygene-3.2.2-py2.py3-none-any.whl (5.4 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from bio) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from biopython>=1.79->bio) (1.21.5)
# Collecting biothings-client>=0.2.6
#   Downloading biothings_client-0.2.6-py2.py3-none-any.whl (37 kB)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->bio) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->bio) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->bio) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->bio) (2021.10.8)
# Installing collected packages: biothings-client, mygene, biopython, bio
# Successfully installed bio-1.3.3 biopython-1.79 biothings-client-0.2.6 mygene-3.2.2

# %%
from zipfile import ZipFile
file_name = "/content/B73-Rhizosphere.zip"

with ZipFile(file_name, 'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
import os
from Bio import SeqIO
import pandas as pd

def get_df(dir):
      a=['A','T','G','C']
      lst=[]
      s=""
      for i in range(0,4):
        s=""
        s=s+a[i]
        for j in range(0,4):
            t=s+a[j]
            for k in range(0,4):
                u=t+a[k]
                for l in range(0,4):
                    v=u+a[l]
                    lst.append(v)
      
      df = pd.DataFrame (lst, columns = ['Combination'])

      directories = os.listdir(dir)
      
      # This would print all the files and directories
      for file in directories:
          filename=str(file).replace(".fa","")
          window_size = 4
          dict1={}
          c=0
          filepath=dir+"/"+str(filename)+".fa"
          boolean=os.path.exists(filepath)
          if boolean==False:
            continue
          for seq_record in SeqIO.parse(filepath, "fasta"):
          #   print(seq_record.id)
              x=seq_record.seq
              for i in range(len(x) - window_size + 1):
                  a=str(x[i: i + window_size])
                  c=c+1
                  if a in dict1:
                      dict1[a]+=1
                  else:
                      dict1[a]=1

          #   print(len(seq_record))
          for k,v in dict1.items():
            dict1[k]=v/c
          df[filename]=df['Combination'].apply(lambda x:  dict1[x] if x in dict1 else 0)
      return df

# %%
Bacteria=get_df("/content/B73-rhizosphere/Bacteria")
Bacteria
# Out:
#     Combination  Rhizo_B73_MAG_00054-contigs  Rhizo_B73_MAG_00012-contigs  \
# 0          AAAA                     0.005013                     0.001584
# 1          AAAT                     0.004087                     0.001818
# 2          AAAG                     0.004475                     0.001860
# 3          AAAC                     0.004199                     0.001616
# 4          AATA                     0.003219                     0.001142
# ..          ...                          ...                          ...
# 251        CCGC                     0.005588                     0.012549
# 252        CCCA                     0.003760                     0.002986
# 253        CCCT                     0.002699                     0.002459
# 254        CCCG                     0.003964                     0.006121
# 255        CCCC                     0.002785                     0.002495
#
#      Rhizo_B73_MAG_00024-contigs  Rhizo_B73_MAG_00028-contigs  \
# 0                       0.000918                     0.001591
# 1                       0.001057                     0.001996
# 2                       0.001667                     0.002050
# 3                       0.001627                     0.001689
# 4                       0.000735                     0.001120
# ..                           ...                          ...
# 251                     0.010213                     0.013103
# 252                     0.003858                     0.002935
# 253                     0.003126                     0.002266
# 254                     0.007099                     0.006302
# 255                     0.003677                     0.002776
#
#      Rhizo_B73_MAG_00045-contigs  Rhizo_B73_MAG_00031-contigs  \
# 0                       0.000822                     0.000207
# 1                       0.000886                     0.000197
# 2                       0.001289                     0.000537
# 3                       0.001248                     0.000514
# 4                       0.000686                     0.000154
# ..                           ...                          ...
# 251                     0.012034                     0.012564
# 252                     0.003658                     0.002604
# 253                     0.003202                     0.002652
# 254                     0.008275                     0.009202
# 255                     0.004629                     0.003599
#
#      Rhizo_B73_MAG_00043-contigs  Rhizo_B73_MAG_00022-contigs  \
# 0                       0.006239                     0.006428
# 1                       0.004652                     0.005205
# 2                       0.005416                     0.004788
# 3                       0.004744                     0.004865
# 4                       0.002776                     0.002286
# ..                           ...                          ...
# 251                     0.005567                     0.006882
# 252                     0.003451                     0.002845
# 253                     0.002611                     0.001877
# 254                     0.003864                     0.003907
# 255                     0.002377                     0.001667
#
#      Rhizo-B73_MAG_00065-contigs  ...  Rhizo_B73_MAG_00033-contigs  \
# 0                       0.001259  ...                     0.008971
# 1                       0.001715  ...                     0.006731
# 2                       0.001845  ...                     0.005400
# 3                       0.001354  ...                     0.005436
# 4                       0.001135  ...                     0.002263
# ..                           ...  ...                          ...
# 251                     0.012351  ...                     0.007371
# 252                     0.002943  ...                     0.002617
# 253                     0.002795  ...                     0.001697
# 254                     0.006567  ...                     0.003900
# 255                     0.002842  ...                     0.001579
#
#      Rhizo_B73_MAG_00036-contigs  Rhizo_B73_MAG_00039-contigs  \
# 0                       0.002191                     0.000090
# 1                       0.002396                     0.000119
# 2                       0.002617                     0.000228
# 3                       0.002271                     0.000275
# 4                       0.001400                     0.000099
# ..                           ...                          ...
# 251                     0.010441                     0.018423
# 252                     0.003175                     0.004150
# 253                     0.002608                     0.004055
# 254                     0.005936                     0.015031
# 255                     0.002746                     0.006615
#
#      Rhizo_B73_MAG_00017-contigs  Rhizo_B73_MAG_00063-contigs  \
# 0                       0.000344                     0.014755
# 1                       0.000468                     0.010462
# 2                       0.000756                     0.006500
# 3                       0.000879                     0.005895
# 4                       0.000377                     0.007841
# ..                           ...                          ...
# 251                     0.014296                     0.003294
# 252                     0.003988                     0.003039
# 253                     0.002999                     0.002828
# 254                     0.010652                     0.003505
# 255                     0.004349                     0.002002
#
#      Rhizo_B73_MAG_00061-contigs  Rhizo_B73_MAG_00016-contigs  \
# 0                       0.000169                     0.006818
# 1                       0.000208                     0.006041
# 2                       0.000482                     0.004052
# 3                       0.000507                     0.004984
# 4                       0.000163                     0.002012
# ..                           ...                          ...
# 251                     0.011958                     0.008833
# 252                     0.003144                     0.002539
# 253                     0.003196                     0.001663
# 254                     0.010178                     0.004674
# 255                     0.004754                     0.001663
#
#      Rhizo_B73_MAG_00055-contigs  Rhizo_B73_MAG_00029-contigs  \
# 0                       0.001382                     0.001646
# 1                       0.001749                     0.001804
# 2                       0.001900                     0.002251
# 3                       0.001506                     0.001806
# 4                       0.001136                     0.001176
# ..                           ...                          ...
# 251                     0.012798                     0.010775
# 252                     0.002851                     0.003185
# 253                     0.002652                     0.002570
# 254                     0.006366                     0.005784
# 255                     0.002520                     0.002795
#
#      Rhizo_B73_MAG_00059-contigs
# 0                       0.001369
# 1                       0.001788
# 2                       0.001925
# 3                       0.001458
# 4                       0.001118
# ..                           ...
# 251                     0.012625
# 252                     0.002822
# 253                     0.002810
# 254                     0.006520
# 255                     0.002699
#
# [256 rows x 62 columns]

# %%
#Change the file extension name in the main script to run virus files (example, virus.fasta)
Virus=get_df("/content/B73-rhizosphere/Virus")
Virus
# Out:
#     Combination  Rhizo_B73_MAG_00001-virus  Rhizo_B73_MAG_00059-virus  \
# 0          AAAA                   0.001569                   0.002621
# 1          AAAT                   0.001255                   0.001572
# 2          AAAG                   0.002511                   0.003669
# 3          AAAC                   0.002825                   0.002621
# 4          AATA                   0.000314                   0.001048
# ..          ...                        ...                        ...
# 251        CCGC                   0.011299                   0.009434
# 252        CCCA                   0.002825                   0.001048
# 253        CCCT                   0.002197                   0.004193
# 254        CCCG                   0.003139                   0.006813
# 255        CCCC                   0.000314                   0.002621
#
#      Rhizo_B73_MAG_00034-virus  Rhizo_B73_MAG_00002-virus  \
# 0                     0.000000                   0.000000
# 1                     0.000000                   0.002082
# 2                     0.000321                   0.001249
# 3                     0.000321                   0.001249
# 4                     0.000000                   0.000416
# ..                         ...                        ...
# 251                   0.009751                   0.010412
# 252                   0.003751                   0.005831
# 253                   0.002357                   0.005414
# 254                   0.007715                   0.006247
# 255                   0.003751                   0.004165
#
#      Rhizo_B73_MAG_00017-virus  Rhizo_B73_MAG_00038-virus  \
# 0                     0.000000                   0.001444
# 1                     0.000306                   0.002475
# 2                     0.000459                   0.003300
# 3                     0.000612                   0.002887
# 4                     0.000000                   0.002062
# ..                         ...                        ...
# 251                   0.013313                   0.008868
# 252                   0.003826                   0.002887
# 253                   0.002601                   0.002475
# 254                   0.010099                   0.006187
# 255                   0.005050                   0.002475
#
#      Rhizo_B73_MAG_00043-virus  Rhizo_B73_MAG_00009-virus  \
# 0                     0.002961                   0.002142
# 1                     0.003780                   0.002410
# 2                     0.004284                   0.002410
# 3                     0.003276                   0.001071
# 4                     0.003402                   0.001606
# ..                         ...                        ...
# 251                   0.006016                   0.009639
# 252                   0.004347                   0.002410
# 253                   0.002929                   0.002410
# 254                   0.004315                   0.004552
# 255                   0.002709                   0.002945
#
#      Rhizo_B73_MAG_00049-virus  ...  Rhizo_B73_MAG_00004-virus  \
# 0                     0.000000  ...                   0.013106
# 1                     0.000000  ...                   0.011602
# 2                     0.000612  ...                   0.008916
# 3                     0.000000  ...                   0.005264
# 4                     0.000000  ...                   0.008594
# ..                         ...  ...                        ...
# 251                   0.008563  ...                   0.003008
# 252                   0.006116  ...                   0.003008
# 253                   0.004281  ...                   0.001934
# 254                   0.009786  ...                   0.001826
# 255                   0.005505  ...                   0.000752
#
#      Rhizo_B73_MAG_00044-virus  Rhizo_B73_MAG_00060-virus  \
# 0                     0.005108                   0.002565
# 1                     0.001572                   0.002565
# 2                     0.004322                   0.002730
# 3                     0.003143                   0.002399
# 4                     0.000786                   0.001406
# ..                         ...                        ...
# 251                   0.007073                   0.010093
# 252                   0.002358                   0.003557
# 253                   0.001179                   0.003309
# 254                   0.005501                   0.005046
# 255                   0.000786                   0.001820
#
#      Rhizo_B73_MAG_00003-virus  Rhizo_B73_MAG_00051-virus  \
# 0                     0.003316                   0.001236
# 1                     0.003934                   0.000000
# 2                     0.003707                   0.001236
# 3                     0.003378                   0.001236
# 4                     0.003563                   0.000000
# ..                         ...                        ...
# 251                   0.003522                   0.004944
# 252                   0.003543                   0.008035
# 253                   0.002533                   0.002472
# 254                   0.002142                   0.010507
# 255                   0.002245                   0.002472
#
#      Rhizo_B73_MAG_00030-virus  Rhizo_B73_MAG_00036-virus  \
# 0                     0.003357                   0.000634
# 1                     0.003357                   0.001268
# 2                     0.002878                   0.005073
# 3                     0.002398                   0.004439
# 4                     0.000000                   0.000634
# ..                         ...                        ...
# 251                   0.011511                   0.006975
# 252                   0.003357                   0.001268
# 253                   0.001439                   0.002536
# 254                   0.005276                   0.003805
# 255                   0.002878                   0.002536
#
#      Rhizo_B73_MAG_00048-virus  Rhizo_B73_MAG_00037-virus  \
# 0                     0.000614                   0.004427
# 1                     0.000000                   0.002767
# 2                     0.000614                   0.002214
# 3                     0.001229                   0.001660
# 4                     0.000000                   0.001107
# ..                         ...                        ...
# 251                   0.011671                   0.011068
# 252                   0.001229                   0.001660
# 253                   0.003071                   0.004981
# 254                   0.008600                   0.004427
# 255                   0.001843                   0.002214
#
#      Rhizo_B73_MAG_00006-virus
# 0                     0.009733
# 1                     0.009332
# 2                     0.008130
# 3                     0.004809
# 4                     0.010019
# ..                         ...
# 251                   0.000744
# 252                   0.001832
# 253                   0.001374
# 254                   0.000401
# 255                   0.000515
#
# [256 rows x 27 columns]

# %%
# !pip install sklearn
from sklearn.metrics import mean_absolute_error as mae
# Out:
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (0.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sklearn) (0.24.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (1.1.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (1.21.5)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (1.4.1)

# %%
from scipy.spatial import distance
from scipy.stats import pearsonr
virus_list=list(Virus.columns[1:])
bacteria_list=list(Bacteria.columns[1:])
lst_corr=[]

for i in virus_list:
  for j in bacteria_list:
    bacteria_series=Bacteria[j]
    virus_series=Virus[i]
    dst = distance.euclidean(bacteria_series, virus_series)
    Absolute = mae(bacteria_series, virus_series)
    corr=pearsonr(bacteria_series, virus_series)[0]
    lst_corr.append((j,i,dst,Absolute,corr))
result=pd.DataFrame(lst_corr,columns = ['MAG','Virus','Euclidean-distance', 'MAE', 'pearson'])
result
# Out:
#                               MAG                      Virus  \
# 0     Rhizo_B73_MAG_00054-contigs  Rhizo_B73_MAG_00001-virus
# 1     Rhizo_B73_MAG_00012-contigs  Rhizo_B73_MAG_00001-virus
# 2     Rhizo_B73_MAG_00024-contigs  Rhizo_B73_MAG_00001-virus
# 3     Rhizo_B73_MAG_00028-contigs  Rhizo_B73_MAG_00001-virus
# 4     Rhizo_B73_MAG_00045-contigs  Rhizo_B73_MAG_00001-virus
# ...                           ...                        ...
# 1581  Rhizo_B73_MAG_00061-contigs  Rhizo_B73_MAG_00006-virus
# 1582  Rhizo_B73_MAG_00016-contigs  Rhizo_B73_MAG_00006-virus
# 1583  Rhizo_B73_MAG_00055-contigs  Rhizo_B73_MAG_00006-virus
# 1584  Rhizo_B73_MAG_00029-contigs  Rhizo_B73_MAG_00006-virus
# 1585  Rhizo_B73_MAG_00059-contigs  Rhizo_B73_MAG_00006-virus
#
#       Euclidean-distance       MAE   pearson
# 0               0.040821  0.001849  0.673524
# 1               0.024928  0.001212  0.873964
# 2               0.026701  0.001281  0.843331
# 3               0.025263  0.001182  0.880070
# 4               0.026717  0.001268  0.847997
# ...                  ...       ...       ...
# 1581            0.087366  0.004343 -0.642942
# 1582            0.057485  0.002695 -0.211667
# 1583            0.075830  0.003589 -0.495245
# 1584            0.069970  0.003379 -0.507738
# 1585            0.076214  0.003619 -0.498841
#
# [1586 rows x 5 columns]

# %%
import numpy as np

def normalize_all(df):
  cols=list(df.columns)
  for col in cols[1:]:
    f=np.sqrt((df[col]*df[col]).sum())
    df[col]=df[col]/f
  return df

# %%
Bacteria2 = normalize_all(Bacteria)
Virus2 = normalize_all(Virus)

# %%
from scipy.spatial import distance
virus_list=list(Virus2.columns[1:])
bacteria_list=list(Bacteria2.columns[1:])
lst_corr=[]

for i in virus_list:
  for j in bacteria_list:
    bacteria_series=Bacteria[j]
    virus_series=Virus[i]
    dst = distance.euclidean(bacteria_series, virus_series)
    lst_corr.append((j,i,dst))
result2=pd.DataFrame(lst_corr,columns = ['MAG','Virus','Euclidean-distance'])
result2
# Out:
#                               MAG                      Virus  \
# 0     Rhizo_B73_MAG_00054-contigs  Rhizo_B73_MAG_00001-virus
# 1     Rhizo_B73_MAG_00012-contigs  Rhizo_B73_MAG_00001-virus
# 2     Rhizo_B73_MAG_00024-contigs  Rhizo_B73_MAG_00001-virus
# 3     Rhizo_B73_MAG_00028-contigs  Rhizo_B73_MAG_00001-virus
# 4     Rhizo_B73_MAG_00045-contigs  Rhizo_B73_MAG_00001-virus
# ...                           ...                        ...
# 1581  Rhizo_B73_MAG_00061-contigs  Rhizo_B73_MAG_00006-virus
# 1582  Rhizo_B73_MAG_00016-contigs  Rhizo_B73_MAG_00006-virus
# 1583  Rhizo_B73_MAG_00055-contigs  Rhizo_B73_MAG_00006-virus
# 1584  Rhizo_B73_MAG_00029-contigs  Rhizo_B73_MAG_00006-virus
# 1585  Rhizo_B73_MAG_00059-contigs  Rhizo_B73_MAG_00006-virus
#
#       Euclidean-distance
# 0               0.527774
# 1               0.312299
# 2               0.339456
# 3               0.311677
# 4               0.337780
# ...                  ...
# 1581            1.094485
# 1582            0.791850
# 1583            0.988635
# 1584            0.939917
# 1585            0.992159
#
# [1586 rows x 3 columns]

# %% [markdown]
# # New Section
