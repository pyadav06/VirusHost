# %% [markdown]
# <a href="https://colab.research.google.com/github/pyadav06/VirusHost/blob/main/Tetranucleotide.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install bio
# Out:
# Requirement already satisfied: bio in /usr/local/lib/python3.7/dist-packages (1.3.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from bio) (2.23.0)
# Requirement already satisfied: biopython>=1.79 in /usr/local/lib/python3.7/dist-packages (from bio) (1.79)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from bio) (4.63.0)
# Requirement already satisfied: mygene in /usr/local/lib/python3.7/dist-packages (from bio) (3.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from biopython>=1.79->bio) (1.21.5)
# Requirement already satisfied: biothings-client>=0.2.6 in /usr/local/lib/python3.7/dist-packages (from mygene->bio) (0.2.6)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->bio) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->bio) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->bio) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->bio) (1.24.3)

# %%
from zipfile import ZipFile
file_name = "/content/Bacteria.zip"

with ZipFile(file_name, 'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
import os
from Bio import SeqIO
import pandas as pd

filepath='/content/Viral-contigs.fasta'
window_size = 4

a=['A','T','G','C']
lst=[]
s=""
for i in range(0,4):
  s=""
  s=s+a[i]
  for j in range(0,4):
      t=s+a[j]
      for k in range(0,4):
          u=t+a[k]
          for l in range(0,4):
              v=u+a[l]
              lst.append(v)
      
df = pd.DataFrame (lst, columns = ['Combination'])

for seq_record in SeqIO.parse(filepath, "fasta"):
#   print(seq_record.id)
    x=seq_record.seq
    dict1={}
    c=0
    for i in range(len(x) - window_size + 1):
        a=str(x[i: i + window_size])
        c=c+1
        if a in dict1:
            dict1[a]+=1
        else:
            dict1[a]=1

    #   print(len(seq_record))
    for k,v in dict1.items():
      dict1[k]=v/c
    df[seq_record.id]=df['Combination'].apply(lambda x:  dict1[x] if x in dict1 else 0)
virus=df
virus
# Out:
#     Combination  c_000000076833  c_000000021950  c_000000031411  \
# 0          AAAA        0.001459        0.000342        0.002435
# 1          AAAT        0.001167        0.002053        0.002191
# 2          AAAG        0.002625        0.002737        0.001948
# 3          AAAC        0.002625        0.002053        0.003165
# 4          AATA        0.000292        0.000342        0.001704
# ..          ...             ...             ...             ...
# 251        CCGC        0.011960        0.009579        0.005357
# 252        CCCA        0.002625        0.004790        0.006574
# 253        CCCT        0.002625        0.005132        0.002678
# 254        CCCG        0.003209        0.005816        0.002435
# 255        CCCC        0.000292        0.003763        0.005600
#
#      c_000000034317  c_000000143073  c_000000136647  c_000000085740  \
# 0          0.006667        0.006483        0.006910        0.003166
# 1          0.003333        0.005943        0.005759        0.003694
# 2          0.007083        0.005943        0.006335        0.001583
# 3          0.003750        0.008104        0.006047        0.001583
# 4          0.001667        0.004862        0.003743        0.004749
# ..              ...             ...             ...             ...
# 251        0.004583        0.002161        0.003455        0.005277
# 252        0.000833        0.003241        0.003167        0.002111
# 253        0.000833        0.005402        0.003455        0.002639
# 254        0.003333        0.000540        0.002879        0.002639
# 255        0.001667        0.002701        0.003167        0.000528
#
#      c_000000069921  c_000000114807  ...  c_000000005663  c_000000136702  \
# 0          0.001715        0.004832  ...        0.001808        0.004245
# 1          0.004630        0.003171  ...        0.007233        0.006604
# 2          0.002401        0.004983  ...        0.003014        0.003302
# 3          0.001200        0.003926  ...        0.004219        0.007075
# 4          0.004802        0.003020  ...        0.004219        0.008019
# ..              ...             ...  ...             ...             ...
# 251        0.002744        0.003171  ...        0.001808        0.006132
# 252        0.002572        0.004832  ...        0.000603        0.002358
# 253        0.002229        0.004077  ...        0.001808        0.002830
# 254        0.002572        0.002265  ...        0.001206        0.005660
# 255        0.002058        0.003624  ...        0.001206        0.004245
#
#      c_000000000859  c_000000008503  c_000000103539  c_000000035520  \
# 0          0.002437        0.007596        0.004839        0.002331
# 1          0.001219        0.004468        0.004839        0.002914
# 2          0.002843        0.006256        0.002258        0.004079
# 3          0.002843        0.002681        0.003871        0.001166
# 4          0.001219        0.002234        0.003226        0.005245
# ..              ...             ...             ...             ...
# 251        0.002031        0.007596        0.002903        0.005245
# 252        0.002843        0.001787        0.006452        0.008159
# 253        0.003656        0.002234        0.004516        0.003497
# 254        0.002031        0.005809        0.004194        0.005828
# 255        0.001219        0.003128        0.002258        0.002914
#
#      c_000000054124  c_000000060603  c_000000101161  c_000000104695
# 0          0.006605        0.005727        0.003849        0.002618
# 1          0.007926        0.002864        0.005773        0.001571
# 2          0.003303        0.004582        0.003849        0.003665
# 3          0.005284        0.006873        0.004490        0.002618
# 4          0.009908        0.006873        0.007056        0.001047
# ..              ...             ...             ...             ...
# 251        0.001982        0.001718        0.002566        0.009424
# 252        0.006605        0.002864        0.003207        0.001047
# 253        0.003963        0.003436        0.002566        0.004188
# 254        0.003963        0.001145        0.003849        0.006806
# 255        0.003963        0.001145        0.001924        0.002618
#
# [256 rows x 83 columns]

# %%
import os
from Bio import SeqIO
import pandas as pd

def get_df(dir):
      a=['A','T','G','C']
      lst=[]
      s=""
      for i in range(0,4):
        s=""
        s=s+a[i]
        for j in range(0,4):
            t=s+a[j]
            for k in range(0,4):
                u=t+a[k]
                for l in range(0,4):
                    v=u+a[l]
                    lst.append(v)
      
      df = pd.DataFrame (lst, columns = ['Combination'])

      directories = os.listdir(dir)
      
      # This would print all the files and directories
      for file in directories:
          filename=str(file).replace(".fa","")
          window_size = 4
          dict1={}
          c=0
          filepath=dir+"/"+str(filename)+".fa"
          boolean=os.path.exists(filepath)
          if boolean==False:
            continue
          for seq_record in SeqIO.parse(filepath, "fasta"):
          #   print(seq_record.id)
              x=seq_record.seq
              for i in range(len(x) - window_size + 1):
                  a=str(x[i: i + window_size])
                  c=c+1
                  if a in dict1:
                      dict1[a]+=1
                  else:
                      dict1[a]=1

          #   print(len(seq_record))
          for k,v in dict1.items():
            dict1[k]=v/c
          df[filename]=df['Combination'].apply(lambda x:  dict1[x] if x in dict1 else 0)
      return df

# %%
Bacteria=get_df("/content/Bacteria/")
Bacteria
# Out:
#     Combination  Rhizo_B73_MAG_00030-contigs  Rhizo_B73_MAG_00051-contigs  \
# 0          AAAA                     0.002566                     0.000996
# 1          AAAT                     0.002337                     0.001047
# 2          AAAG                     0.002837                     0.001696
# 3          AAAC                     0.002207                     0.001702
# 4          AATA                     0.001439                     0.000727
# ..          ...                          ...                          ...
# 251        CCGC                     0.011728                     0.010351
# 252        CCCA                     0.004288                     0.003917
# 253        CCCT                     0.003082                     0.003065
# 254        CCCG                     0.006162                     0.007063
# 255        CCCC                     0.003156                     0.003555
#
#      Rhizo_B73_MAG_00010-contigs  Rhizo_B73_MAG_00045-contigs  \
# 0                       0.000167                     0.000822
# 1                       0.000164                     0.000886
# 2                       0.000527                     0.001289
# 3                       0.000465                     0.001248
# 4                       0.000106                     0.000686
# ..                           ...                          ...
# 251                     0.016162                     0.012034
# 252                     0.002719                     0.003658
# 253                     0.002540                     0.003202
# 254                     0.009205                     0.008275
# 255                     0.003288                     0.004629
#
#      Rhizo_B73_MAG_00032-contigs  Rhizo_B73_MAG_00060-contigs  \
# 0                       0.006522                     0.002949
# Out:
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (0.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sklearn) (1.0.2)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (1.1.0)
# Requirement already satisfied: numpy>=1.14.6 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (1.21.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (3.1.0)

# %%
from scipy.spatial import distance
from scipy.stats import pearsonr
virus_list=list(virus.columns[1:])
bacteria_list=list(Bacteria.columns[1:])
lst_corr=[]

for i in virus_list:
  for j in bacteria_list:
    bacteria_series=Bacteria[j]
    virus_series=virus[i]
    dst = distance.euclidean(bacteria_series, virus_series)
    Absolute = mae(bacteria_series, virus_series)
    corr=pearsonr(bacteria_series, virus_series)[0]
    lst_corr.append((j,i,dst,Absolute,corr))
result=pd.DataFrame(lst_corr,columns = ['MAG','Virus','Euclidean-distance', 'MAE', 'pearson'])
result
# Out:
#                               MAG           Virus  Euclidean-distance  \
# 0     Rhizo_B73_MAG_00030-contigs  c_000000076833            0.027135
# 1     Rhizo_B73_MAG_00051-contigs  c_000000076833            0.026647
# 2     Rhizo_B73_MAG_00010-contigs  c_000000076833            0.037954
# 3     Rhizo_B73_MAG_00045-contigs  c_000000076833            0.026296
# 4     Rhizo_B73_MAG_00032-contigs  c_000000076833            0.035392
# ...                           ...             ...                 ...
# 4997  Rhizo_B73_MAG_00059-contigs  c_000000104695            0.026070
# 4998  Rhizo_B73_MAG_00050-contigs  c_000000104695            0.025437
# 4999  Rhizo_B73_MAG_00024-contigs  c_000000104695            0.026592
# 5000  Rhizo_B73_MAG_00007-contigs  c_000000104695            0.037057
# 5001  Rhizo_B73_MAG_00041-contigs  c_000000104695            0.038711
#
#            MAE   pearson
# 0     0.001289  0.836613
# 1     0.001262  0.844664
# 2     0.001715  0.858405
# 3     0.001245  0.852833
# 4     0.001650  0.717361
# ...        ...       ...
# 4997  0.001219  0.864863
# 4998  0.001200  0.869763
# 4999  0.001223  0.848068
# 5000  0.001716  0.674089
# 5001  0.001785  0.633792
#
# [5002 rows x 5 columns]

# %%
from scipy.spatial import distance
virus_list=list(Virus2.columns[1:])
bacteria_list=list(Bacteria2.columns[1:])
lst_corr=[]

for i in virus_list:
  for j in bacteria_list:
    bacteria_series=Bacteria[j]
    virus_series=Virus[i]
    dst = distance.euclidean(bacteria_series, virus_series)
    lst_corr.append((j,i,dst))
result2=pd.DataFrame(lst_corr,columns = ['MAG','Virus','Euclidean-distance'])
result2
# Out:
#                               MAG                      Virus  \
# 0     Rhizo_B73_MAG_00054-contigs  Rhizo_B73_MAG_00001-virus
# 1     Rhizo_B73_MAG_00012-contigs  Rhizo_B73_MAG_00001-virus
# 2     Rhizo_B73_MAG_00024-contigs  Rhizo_B73_MAG_00001-virus
# 3     Rhizo_B73_MAG_00028-contigs  Rhizo_B73_MAG_00001-virus
# 4     Rhizo_B73_MAG_00045-contigs  Rhizo_B73_MAG_00001-virus
# ...                           ...                        ...
# 1581  Rhizo_B73_MAG_00061-contigs  Rhizo_B73_MAG_00006-virus
# 1582  Rhizo_B73_MAG_00016-contigs  Rhizo_B73_MAG_00006-virus
# 1583  Rhizo_B73_MAG_00055-contigs  Rhizo_B73_MAG_00006-virus
# 1584  Rhizo_B73_MAG_00029-contigs  Rhizo_B73_MAG_00006-virus
# 1585  Rhizo_B73_MAG_00059-contigs  Rhizo_B73_MAG_00006-virus
#
#       Euclidean-distance
# 0               0.527774
# 1               0.312299
# 2               0.339456
# 3               0.311677
# 4               0.337780
# ...                  ...
# 1581            1.094485
# 1582            0.791850
# 1583            0.988635
# 1584            0.939917
# 1585            0.992159
#
# [1586 rows x 3 columns]

# %% [markdown]
# # New Section
