# %% [markdown]
# <a href="https://colab.research.google.com/github/pyadav06/VirusHost/blob/main/Normalization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import preprocessing
